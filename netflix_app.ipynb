# %% [markdown]
# --NETFLIX APP--

# %%
cust_name = input("Enter user id :- ")
password = input("Enter password :- ")

# %%
print("welcome to netflix....")

for i in range(1,4):
    c_name = input("Enter user id :- ")
    c_pass = input("Enter password :- ")
    if c_name == cust_name and c_pass == password :
        print("login successfuly.....")
        print("welcome   " + c_name)
        break
    else:
        print("login failed....")
        print(f"login failed ! attemp {i} of 3.")
# Out:
# welcome to netflix....
# login successfuly.....
# welcome   yash

# %%
print("welcome to netflix " + c_name)
print("1.basic paln")
print("2.standard plan")
print("3.premium plan")

choice = input("enter your number which plan you choose")

if choice == "1" :
    print("you can choose basic plan")
elif choice == "2" :
    print("you can choose standard plan")
elif choice == "3" :
    print("you can choose premium plan..")
else:
    print("invalid try again later")
    exit
# Out:
# welcome to netflix yash
# 1.basic paln
# 2.standard plan
# 3.premium plan
# you can choose standard plan

# %%
movies = ["koi mil gaya..","krish","bahubali","bahubali 3"]
print("available movies :- ")
for movies in movies :
    print(f"-{movies}")
# Out:
# available movies :-
# -koi mil gaya..
# -krish
# -bahubali
# -bahubali 3
